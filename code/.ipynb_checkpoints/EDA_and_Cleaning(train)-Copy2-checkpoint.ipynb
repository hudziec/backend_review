# %% [markdown]
# **Description of the Ames Iowa Housing Data columns:**

# %% [markdown]
# SOURCE: https://rdrr.io/cran/AmesHousing/man/ames_raw.html
#
# Order: Observation number
#
# PID: Parcel identification number - can be used with city web site for parcel review.
#
# MS SubClass: Identifies the type of dwelling involved in the sale.
#
# MS Zoning: Identifies the general zoning classification of the sale.
#
# Lot Frontage: Linear feet of street connected to property
#
# Lot Area: Lot size in square feet
#
# Street: Type of road access to property
#
# Alley: Type of alley access to property
#
# Lot Shape: General shape of property
#
# Land Contour: Flatness of the property
#
# Utilities: Type of utilities available
#
# Lot Config: Lot configuration
#
# Land Slope: Slope of property
#
# Neighborhood: Physical locations within Ames city limits (map available)
#
# Condition 1: Proximity to various conditions
#
# Condition 2: Proximity to various conditions (if more than one is present)
#
# Bldg Type: Type of dwelling
#
# House Style: Style of dwelling
#
# Overall Qual: Rates the overall material and finish of the house
#
# Overall Cond: Rates the overall condition of the house
#
# Year Built: Original construction date
#
# Year Remod/Add: Remodel date (same as construction date if no remodeling or additions)
#
# Roof Style: Type of roof
#
# Roof Matl: Roof material
#
# Exterior 1: Exterior covering on house
#
# Exterior 2: Exterior covering on house (if more than one material)
#
# Mas Vnr Type: Masonry veneer type
#
# Mas Vnr Area: Masonry veneer area in square feet
#
# Exter Qual: Evaluates the quality of the material on the exterior
#
# Exter Cond: Evaluates the present condition of the material on the exterior
#
# Foundation: Type of foundation
#
# Bsmt Qual: Evaluates the height of the basement
#
# Bsmt Cond: Evaluates the general condition of the basement
#
# Bsmt Exposure: Refers to walkout or garden level walls
#
# BsmtFin Type 1: Rating of basement finished area
#
# BsmtFin SF 1: Type 1 finished square feet
#
# BsmtFinType 2: Rating of basement finished area (if multiple types)
#
# BsmtFin SF 2: Type 2 finished square feet
#
# Bsmt Unf SF: Unfinished square feet of basement area
#
# Total Bsmt SF: Total square feet of basement area
#
# Heating: Type of heating
#
# HeatingQC: Heating quality and condition
#
# Central Air: Central air conditioning
#
# Electrical: Electrical system
#
# 1st Flr SF: First Floor square feet
#
# 2nd Flr SF: Second floor square feet
#
# Low Qual Fin SF: Low quality finished square feet (all floors)
#
# Gr Liv Area: Above grade (ground) living area square feet
#
# Bsmt Full Bath: Basement full bathrooms
#
# Bsmt Half Bath: Basement half bathrooms
#
# Full Bath: Full bathrooms above grade
#
# Half Bath: Half baths above grade
#
# Bedroom: Bedrooms above grade (does NOT include basement bedrooms)
#
# Kitchen: Kitchens above grade
#
# KitchenQual: Kitchen quality
#
# TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
#
# Functional: Home functionality (Assume typical unless deductions are warranted)
#
# Fireplaces: Number of fireplaces
#
# FireplaceQu: Fireplace quality
#
# Garage Type: Garage location
#
# Garage Yr Blt: Year garage was built
#
# Garage Finish: Interior finish of the garage
#
# Garage Cars: Size of garage in car capacity
#
# Garage Area: Size of garage in square feet
#
# Garage Qual: Garage quality
#
# Garage Cond: Garage condition
#
# Paved Drive: Paved driveway
#
# Wood Deck SF: Wood deck area in square feet
#
# Open Porch SF: Open porch area in square feet
#
# Enclosed Porch: Enclosed porch area in square feet
#
# 3-Ssn Porch: Three season porch area in square feet
#
# Screen Porch: Screen porch area in square feet
#
# Pool Area: Pool area in square feet
#
# Pool QC: Pool quality
#
# Fence: Fence quality
#
# Misc Feature: Miscellaneous feature not covered in other categories
#
# Misc Val: $Value of miscellaneous feature
#
# Mo Sold: Month Sold
#
# Yr Sold: Year Sold
#
# Sale Type: Type of sale
#
# Sale Condition: Condition of sale

# %% [markdown]
# **Load packages:**

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %% [markdown]
#  **Load the data:**

# %%
ames_file_train = '../data/train.csv'

# %%
df = pd.read_csv(ames_file_train)

# %% [markdown]
# **Describe the basic format:**

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

# %%
df.dtypes
# Out:
# Id                   int64
# PID                  int64
# MS SubClass          int64
# MS Zoning           object
# Lot Frontage       float64
# Lot Area             int64
# Street              object
# Alley               object
# Lot Shape           object
# Land Contour        object
# Utilities           object
# Lot Config          object
# Land Slope          object
# Neighborhood        object
# Condition 1         object
# Condition 2         object
# Bldg Type           object
# House Style         object
# Overall Qual         int64
# Overall Cond         int64
# Year Built           int64
# Year Remod/Add       int64
# Roof Style          object
# Roof Matl           object
# Exterior 1st        object
# Exterior 2nd        object
# Mas Vnr Type        object
# Mas Vnr Area       float64
# Exter Qual          object
# Exter Cond          object
# Foundation          object
# Bsmt Qual           object
# Bsmt Cond           object
# Bsmt Exposure       object
# BsmtFin Type 1      object
# BsmtFin SF 1       float64
# BsmtFin Type 2      object
# BsmtFin SF 2       float64
# Bsmt Unf SF        float64
# Total Bsmt SF      float64
# Heating             object
# Heating QC          object
# Central Air         object
# Electrical          object
# 1st Flr SF           int64
# 2nd Flr SF           int64
# Low Qual Fin SF      int64
# Gr Liv Area          int64
# Bsmt Full Bath     float64
# Bsmt Half Bath     float64
# Full Bath            int64
# Half Bath            int64
# Bedroom AbvGr        int64
# Kitchen AbvGr        int64
# Kitchen Qual        object
# TotRms AbvGrd        int64
# Functional          object
# Fireplaces           int64
# Fireplace Qu        object
# Garage Type         object
# Garage Yr Blt      float64
# Garage Finish       object
# Garage Cars        float64
# Garage Area        float64
# Garage Qual         object
# Garage Cond         object
# Paved Drive         object
# Wood Deck SF         int64
# Open Porch SF        int64
# Enclosed Porch       int64
# 3Ssn Porch           int64
# Screen Porch         int64
# Pool Area            int64
# Pool QC             object
# Fence               object
# Misc Feature        object
# Misc Val             int64
# Mo Sold              int64
# Yr Sold              int64
# Sale Type           object
# SalePrice            int64
# dtype: object

# %%
df.head(5)
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0   NaN          NaN         0        3     2010       WD      130500
# 1   NaN          NaN         0        4     2009       WD      220000
# 2   NaN          NaN         0        1     2010       WD      109000
# 3   NaN          NaN         0        4     2010       WD      174000
# 4   NaN          NaN         0        3     2010       WD      138500

# %%
df.shape
# Out:
# (2051, 81)

# %% [markdown]
# **Re-organize data:**

# %%
ames_file_train = '../data/train.csv'

# %%
df = pd.read_csv(ames_file_train, index_col="Id")

# %%
df = df.sort_values(by='Id')

# %%
df.index = df.index.set_names([''])

# %%
df.head(5)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
#
# 1  526301100           20        RL         141.0     31770   Pave   NaN
# 3  526351010           20        RL          81.0     14267   Pave   NaN
# 5  527105010           60        RL          74.0     13830   Pave   NaN
# 8  527145080          120        RL          43.0      5005   Pave   NaN
# 9  527146030          120        RL          39.0      5389   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
#
# 1       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 3       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 5       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 8       IR1          HLS    AllPub     Inside        Gtl      StoneBr
# 9       IR1          Lvl    AllPub     Inside        Gtl      StoneBr
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
#
# 1        Norm        Norm      1Fam      1Story             6             5
# 3        Norm        Norm      1Fam      1Story             6             6
# 5        Norm        Norm      1Fam      2Story             5             5
# 8        Norm        Norm    TwnhsE      1Story             8             5
# 9        Norm        Norm    TwnhsE      1Story             8             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
#
# 1        1960            1960        Hip   CompShg      BrkFace      Plywood
# 3        1958            1958        Hip   CompShg      Wd Sdng      Wd Sdng
# 5        1997            1998      Gable   CompShg      VinylSd      VinylSd
# 8        1992            1992      Gable   CompShg      HdBoard      HdBoard
# 9        1995            1996      Gable   CompShg      CemntBd      CmentBd
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
#
# 1        Stone         112.0         TA         TA     CBlock        TA
# 3      BrkFace         108.0         TA         TA     CBlock        TA
# 5         None           0.0         TA         TA      PConc        Gd
# 8         None           0.0         Gd         TA      PConc        Gd
# 9         None           0.0         Gd         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
#
# 1        Gd            Gd            BLQ         639.0            Unf
# 3        TA            No            ALQ         923.0            Unf
# 5        TA            No            GLQ         791.0            Unf
# 8        TA            No            ALQ         263.0            Unf
# 9        TA            No            GLQ        1180.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
#
# 1           0.0        441.0         1080.0    GasA         Fa           Y
# 3           0.0        406.0         1329.0    GasA         TA           Y
# 5           0.0        137.0          928.0    GasA         Gd           Y
# 8           0.0       1017.0         1280.0    GasA         Ex           Y
# 9           0.0        415.0         1595.0    GasA         Ex           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
#
# 1      SBrkr        1656           0                0         1656
# 3      SBrkr        1329           0                0         1329
# 5      SBrkr         928         701                0         1629
# 8      SBrkr        1280           0                0         1280
# 9      SBrkr        1616           0                0         1616
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
#
# 1             1.0             0.0          1          0              3
# 3             0.0             0.0          1          1              3
# 5             0.0             0.0          2          1              3
# 8             0.0             0.0          2          0              2
# 9             1.0             0.0          2          0              2
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
#
# 1              1           TA              7        Typ           2
# 3              1           Gd              6        Typ           0
# 5              1           TA              6        Typ           1
# 8              1           Gd              5        Typ           0
# 9              1           Gd              5        Typ           1
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
#
# 1           Gd      Attchd         1960.0           Fin          2.0
# 3          NaN      Attchd         1958.0           Unf          1.0
# 5           TA      Attchd         1997.0           Fin          2.0
# 8          NaN      Attchd         1992.0           RFn          2.0
# 9           TA      Attchd         1995.0           RFn          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
#
# 1        528.0          TA          TA           P           210
# 3        312.0          TA          TA           Y           393
# 5        482.0          TA          TA           Y           212
# 8        506.0          TA          TA           Y             0
# 9        608.0          TA          TA           Y           237
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
#
# 1             62               0           0             0          0     NaN
# 3             36               0           0             0          0     NaN
# 5             34               0           0             0          0     NaN
# 8             82               0           0           144          0     NaN
# 9            152               0           0             0          0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
#
# 1    NaN          NaN         0        5     2010       WD      215000
# 3    NaN         Gar2     12500        6     2010       WD      172000
# 5  MnPrv          NaN         0        3     2010       WD      189900
# 8    NaN          NaN         0        1     2010       WD      191500
# 9    NaN          NaN         0        3     2010       WD      236500

# %%
df.shape
# Out:
# (2051, 80)

# %% [markdown]
# **Drop unwanted columns:**

# %% [markdown]
# * SAVE AS MUCH AS THE DATA AS YOU CAN, ONLY DROP COLUMNS THAT MODELS WILL NOT NEED (PID)

# %%
df.drop(columns=['PID'], inplace=True)

# %%
df.head(5)
# Out:
#    MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley Lot Shape  \
#
# 1           20        RL         141.0     31770   Pave   NaN       IR1
# 3           20        RL          81.0     14267   Pave   NaN       IR1
# 5           60        RL          74.0     13830   Pave   NaN       IR1
# 8          120        RL          43.0      5005   Pave   NaN       IR1
# 9          120        RL          39.0      5389   Pave   NaN       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
#
# 1          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 5          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 8          HLS    AllPub     Inside        Gtl      StoneBr        Norm
# 9          Lvl    AllPub     Inside        Gtl      StoneBr        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
#
# 1        Norm      1Fam      1Story             6             5        1960
# 3        Norm      1Fam      1Story             6             6        1958
# 5        Norm      1Fam      2Story             5             5        1997
# 8        Norm    TwnhsE      1Story             8             5        1992
# 9        Norm    TwnhsE      1Story             8             5        1995
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
#
# 1            1960        Hip   CompShg      BrkFace      Plywood        Stone
# 3            1958        Hip   CompShg      Wd Sdng      Wd Sdng      BrkFace
# 5            1998      Gable   CompShg      VinylSd      VinylSd         None
# 8            1992      Gable   CompShg      HdBoard      HdBoard         None
# 9            1996      Gable   CompShg      CemntBd      CmentBd         None
#
#    Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond  \
#
# 1         112.0         TA         TA     CBlock        TA        Gd
# 3         108.0         TA         TA     CBlock        TA        TA
# 5           0.0         TA         TA      PConc        Gd        TA
# 8           0.0         Gd         TA      PConc        Gd        TA
# 9           0.0         Gd         TA      PConc        Gd        TA
#
#   Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
#
# 1            Gd            BLQ         639.0            Unf           0.0
# 3            No            ALQ         923.0            Unf           0.0
# 5            No            GLQ         791.0            Unf           0.0
# 8            No            ALQ         263.0            Unf           0.0
# 9            No            GLQ        1180.0            Unf           0.0
#
#    Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air Electrical  \
#
# 1        441.0         1080.0    GasA         Fa           Y      SBrkr
# 3        406.0         1329.0    GasA         TA           Y      SBrkr
# 5        137.0          928.0    GasA         Gd           Y      SBrkr
# 8       1017.0         1280.0    GasA         Ex           Y      SBrkr
# 9        415.0         1595.0    GasA         Ex           Y      SBrkr
#
#    1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
#
# 1        1656           0                0         1656             1.0
# 3        1329           0                0         1329             0.0
# 5         928         701                0         1629             0.0
# 8        1280           0                0         1280             0.0
# 9        1616           0                0         1616             1.0
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
#
# 1             0.0          1          0              3              1
# 3             0.0          1          1              3              1
# 5             0.0          2          1              3              1
# 8             0.0          2          0              2              1
# 9             0.0          2          0              2              1
#
#   Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu Garage Type  \
#
# 1           TA              7        Typ           2           Gd      Attchd
# 3           Gd              6        Typ           0          NaN      Attchd
# 5           TA              6        Typ           1           TA      Attchd
# 8           Gd              5        Typ           0          NaN      Attchd
# 9           Gd              5        Typ           1           TA      Attchd
#
#    Garage Yr Blt Garage Finish  Garage Cars  Garage Area Garage Qual  \
#
# 1         1960.0           Fin          2.0        528.0          TA
# 3         1958.0           Unf          1.0        312.0          TA
# 5         1997.0           Fin          2.0        482.0          TA
# 8         1992.0           RFn          2.0        506.0          TA
# 9         1995.0           RFn          2.0        608.0          TA
#
#   Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
#
# 1          TA           P           210             62               0
# 3          TA           Y           393             36               0
# 5          TA           Y           212             34               0
# 8          TA           Y             0             82               0
# 9          TA           Y           237            152               0
#
#    3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence Misc Feature  Misc Val  \
#
# 1           0             0          0     NaN    NaN          NaN         0
# 3           0             0          0     NaN    NaN         Gar2     12500
# 5           0             0          0     NaN  MnPrv          NaN         0
# 8           0           144          0     NaN    NaN          NaN         0
# 9           0             0          0     NaN    NaN          NaN         0
#
#    Mo Sold  Yr Sold Sale Type  SalePrice
#
# 1        5     2010       WD      215000
# 3        6     2010       WD      172000
# 5        3     2010       WD      189900
# 8        1     2010       WD      191500
# 9        3     2010       WD      236500

# %% [markdown]
# **Determine missing observations:**

# %%
df.isnull().sum()
# Out:
# MS SubClass           0
# MS Zoning             0
# Lot Frontage        330
# Lot Area              0
# Street                0
# Alley              1911
# Lot Shape             0
# Land Contour          0
# Utilities             0
# Lot Config            0
# Land Slope            0
# Neighborhood          0
# Condition 1           0
# Condition 2           0
# Bldg Type             0
# House Style           0
# Overall Qual          0
# Overall Cond          0
# Year Built            0
# Year Remod/Add        0
# Roof Style            0
# Roof Matl             0
# Exterior 1st          0
# Exterior 2nd          0
# Mas Vnr Type         22
# Mas Vnr Area         22
# Exter Qual            0
# Exter Cond            0
# Foundation            0
# Bsmt Qual            55
# Bsmt Cond            55
# Bsmt Exposure        58
# BsmtFin Type 1       55
# BsmtFin SF 1          1
# BsmtFin Type 2       56
# BsmtFin SF 2          1
# Bsmt Unf SF           1
# Total Bsmt SF         1
# Heating               0
# Heating QC            0
# Central Air           0
# Electrical            0
# 1st Flr SF            0
# 2nd Flr SF            0
# Low Qual Fin SF       0
# Gr Liv Area           0
# Bsmt Full Bath        2
# Bsmt Half Bath        2
# Full Bath             0
# Half Bath             0
# Bedroom AbvGr         0
# Kitchen AbvGr         0
# Kitchen Qual          0
# TotRms AbvGrd         0
# Functional            0
# Fireplaces            0
# Fireplace Qu       1000
# Garage Type         113
# Garage Yr Blt       114
# Garage Finish       114
# Garage Cars           1
# Garage Area           1
# Garage Qual         114
# Garage Cond         114
# Paved Drive           0
# Wood Deck SF          0
# Open Porch SF         0
# Enclosed Porch        0
# 3Ssn Porch            0
# Screen Porch          0
# Pool Area             0
# Pool QC            2042
# Fence              1651
# Misc Feature       1986
# Misc Val              0
# Mo Sold               0
# Yr Sold               0
# Sale Type             0
# SalePrice             0
# dtype: int64

# %% [markdown]
# **Make the column names searchable**

# %%
df.columns = df.columns.str.replace('3','three')

# %%
df.columns = df.columns.str.replace('1st','first')

# %%
df.columns = df.columns.str.replace('/','_')

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.columns = df.columns.str.lower()

# %%
df.dtypes
# Out:
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod_add       int64
# roof_style          object
# roof_matl           object
# exterior_first      object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1       float64
# bsmtfin_type_2      object
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# first_flr_sf         int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars        float64
# garage_area        float64
# garage_qual         object
# garage_cond         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# threessn_porch       int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# saleprice            int64
# dtype: object

# %% [markdown]
# **Analyze & Evaluate Columns**

# %% [markdown]
# * I will try and predict housing prices, any data that could by useful in this task will be kept.

# %%
# COLUMN:		ms_subclass
# DEFINITION:	Identifies the type of dwelling involved in the sale.
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.ms_subclass.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING VALUES!
# Out:
# array([ 20,  60, 120, 160,  80,  50,  90,  30, 190,  70,  85,  75,  45,
#        180,  40, 150])

# %%
# COLUMN:		ms_zoning
# DEFINITION:	Identifies the general zoning classification of the sale.
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. ms_zoning.unique()
# EVALUATION: COLUMN NEEDS TO BE CONVERTED TO INTERGER, NO MISSING VALUES!
# Out:
# array(['RL', 'FV', 'RH', 'RM', 'C (all)', 'I (all)', 'A (agr)'],
#       dtype=object)

# %%
ms_zoning = {'RL':'0', 'FV':'1', 'RH':'2', 'RM':'3', 'C (all)':'4', 'I (all)':'5', 'A (agr)':'6'}

# %%
df.ms_zoning = [ms_zoning[item] for item in df.ms_zoning]

# %%
df.ms_zoning.unique()
# Out:
# array(['0', '1', '2', '3', '4', '5', '6'], dtype=object)

# %%
df["ms_zoning"] = df["ms_zoning"].astype(dtype=np.int)

# %%
df['ms_zoning'].dtype
# Out:
# dtype('int64')

# %%
df.head(5)
# Out:
#    ms_subclass  ms_zoning  lot_frontage  lot_area street alley lot_shape  \
#
# 1           20          0         141.0     31770   Pave   NaN       IR1
# 3           20          0          81.0     14267   Pave   NaN       IR1
# 5           60          0          74.0     13830   Pave   NaN       IR1
# 8          120          0          43.0      5005   Pave   NaN       IR1
# 9          120          0          39.0      5389   Pave   NaN       IR1
#
#   land_contour utilities lot_config land_slope neighborhood condition_1  \
#
# 1          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 3          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 5          Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 8          HLS    AllPub     Inside        Gtl      StoneBr        Norm
# 9          Lvl    AllPub     Inside        Gtl      StoneBr        Norm
#
#   condition_2 bldg_type house_style  overall_qual  overall_cond  year_built  \
#
# 1        Norm      1Fam      1Story             6             5        1960
# 3        Norm      1Fam      1Story             6             6        1958
# 5        Norm      1Fam      2Story             5             5        1997
# 8        Norm    TwnhsE      1Story             8             5        1992
# 9        Norm    TwnhsE      1Story             8             5        1995
#
#    year_remod_add roof_style roof_matl exterior_first exterior_2nd  \
#
# 1            1960        Hip   CompShg        BrkFace      Plywood
# 3            1958        Hip   CompShg        Wd Sdng      Wd Sdng
# 5            1998      Gable   CompShg        VinylSd      VinylSd
# 8            1992      Gable   CompShg        HdBoard      HdBoard
# 9            1996      Gable   CompShg        CemntBd      CmentBd
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
#
# 1        Stone         112.0         TA         TA     CBlock        TA
# 3      BrkFace         108.0         TA         TA     CBlock        TA
# 5         None           0.0         TA         TA      PConc        Gd
# 8         None           0.0         Gd         TA      PConc        Gd
# 9         None           0.0         Gd         TA      PConc        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
#
# 1        Gd            Gd            BLQ         639.0            Unf
# 3        TA            No            ALQ         923.0            Unf
# 5        TA            No            GLQ         791.0            Unf
# 8        TA            No            ALQ         263.0            Unf
# 9        TA            No            GLQ        1180.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
#
# 1           0.0        441.0         1080.0    GasA         Fa           Y
# 3           0.0        406.0         1329.0    GasA         TA           Y
# 5           0.0        137.0          928.0    GasA         Gd           Y
# 8           0.0       1017.0         1280.0    GasA         Ex           Y
# 9           0.0        415.0         1595.0    GasA         Ex           Y
#
#   electrical  first_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
#
# 1      SBrkr          1656           0                0         1656
# 3      SBrkr          1329           0                0         1329
# 5      SBrkr           928         701                0         1629
# 8      SBrkr          1280           0                0         1280
# 9      SBrkr          1616           0                0         1616
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
#
# 1             1.0             0.0          1          0              3
# 3             0.0             0.0          1          1              3
# 5             0.0             0.0          2          1              3
# 8             0.0             0.0          2          0              2
# 9             1.0             0.0          2          0              2
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
#
# 1              1           TA              7        Typ           2
# 3              1           Gd              6        Typ           0
# 5              1           TA              6        Typ           1
# 8              1           Gd              5        Typ           0
# 9              1           Gd              5        Typ           1
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
#
# 1           Gd      Attchd         1960.0           Fin          2.0
# 3          NaN      Attchd         1958.0           Unf          1.0
# 5           TA      Attchd         1997.0           Fin          2.0
# 8          NaN      Attchd         1992.0           RFn          2.0
# 9           TA      Attchd         1995.0           RFn          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
#
# 1        528.0          TA          TA           P           210
# 3        312.0          TA          TA           Y           393
# 5        482.0          TA          TA           Y           212
# 8        506.0          TA          TA           Y             0
# 9        608.0          TA          TA           Y           237
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
#
# 1             62               0               0             0          0
# 3             36               0               0             0          0
# 5             34               0               0             0          0
# 8             82               0               0           144          0
# 9            152               0               0             0          0
#
#   pool_qc  fence misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
#
# 1     NaN    NaN          NaN         0        5     2010       WD      215000
# 3     NaN    NaN         Gar2     12500        6     2010       WD      172000
# 5     NaN  MnPrv          NaN         0        3     2010       WD      189900
# 8     NaN    NaN          NaN         0        1     2010       WD      191500
# 9     NaN    NaN          NaN         0        3     2010       WD      236500

# %%
# COLUMN:		lot_frontage
# DEFINITION:	Linear feet of street connected to property
# DATA TYPE:	float64
# MISSING VALUES:	330
# UNIQUE VALUES:	
df.lot_frontage.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING VALUES, COLUMN TO BE DROPPED!
# Out:
# array([141.,  81.,  74.,  43.,  39.,  60.,  75.,  nan,  63.,  85.,  47.,
#        140., 105.,  65.,  70.,  26.,  21.,  53.,  24., 102.,  98.,  95.,
#         79., 100., 110.,  61.,  41.,  36.,  67., 108.,  59.,  92.,  58.,
#         56.,  73.,  72.,  76.,  50.,  55.,  68., 107.,  25.,  30.,  57.,
#         40.,  80.,  77.,  90.,  88., 120., 137., 119.,  78.,  71.,  87.,
#         69.,  52.,  51.,  54.,  94.,  44.,  83.,  64.,  82.,  38.,  48.,
#         89.,  66.,  35., 129.,  93.,  42.,  99.,  96., 104.,  97., 103.,
#         34., 117.,  62., 174., 106.,  84., 128.,  91., 144., 122., 112.,
#         86.,  45., 130., 109., 113., 125., 101.,  46., 114., 135.,  37.,
#         22.,  32., 313.,  49., 124., 123., 150., 160., 195., 118., 134.,
#        116., 138., 155., 115., 200., 111., 121.,  33., 153.])

# %%
df = df.drop(columns=['lot_frontage'])

# %%
df.head(5)
# Out:
#    ms_subclass  ms_zoning  lot_area street alley lot_shape land_contour  \
#
# 1           20          0     31770   Pave   NaN       IR1          Lvl
# 3           20          0     14267   Pave   NaN       IR1          Lvl
# 5           60          0     13830   Pave   NaN       IR1          Lvl
# 8          120          0      5005   Pave   NaN       IR1          HLS
# 9          120          0      5389   Pave   NaN       IR1          Lvl
#
#   utilities lot_config land_slope neighborhood condition_1 condition_2  \
#
# 1    AllPub     Corner        Gtl        NAmes        Norm        Norm
# 3    AllPub     Corner        Gtl        NAmes        Norm        Norm
# 5    AllPub     Inside        Gtl      Gilbert        Norm        Norm
# 8    AllPub     Inside        Gtl      StoneBr        Norm        Norm
# 9    AllPub     Inside        Gtl      StoneBr        Norm        Norm
#
#   bldg_type house_style  overall_qual  overall_cond  year_built  \
#
# 1      1Fam      1Story             6             5        1960
# 3      1Fam      1Story             6             6        1958
# 5      1Fam      2Story             5             5        1997
# 8    TwnhsE      1Story             8             5        1992
# 9    TwnhsE      1Story             8             5        1995
#
#    year_remod_add roof_style roof_matl exterior_first exterior_2nd  \
#
# 1            1960        Hip   CompShg        BrkFace      Plywood
# 3            1958        Hip   CompShg        Wd Sdng      Wd Sdng
# 5            1998      Gable   CompShg        VinylSd      VinylSd
# 8            1992      Gable   CompShg        HdBoard      HdBoard
# 9            1996      Gable   CompShg        CemntBd      CmentBd
#
#   mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation bsmt_qual  \
#
# 1        Stone         112.0         TA         TA     CBlock        TA
# 3      BrkFace         108.0         TA         TA     CBlock        TA
# 5         None           0.0         TA         TA      PConc        Gd
# 8         None           0.0         Gd         TA      PConc        Gd
# 9         None           0.0         Gd         TA      PConc        Gd
#
#   bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  \
#
# 1        Gd            Gd            BLQ         639.0            Unf
# 3        TA            No            ALQ         923.0            Unf
# 5        TA            No            GLQ         791.0            Unf
# 8        TA            No            ALQ         263.0            Unf
# 9        TA            No            GLQ        1180.0            Unf
#
#    bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc central_air  \
#
# 1           0.0        441.0         1080.0    GasA         Fa           Y
# 3           0.0        406.0         1329.0    GasA         TA           Y
# 5           0.0        137.0          928.0    GasA         Gd           Y
# 8           0.0       1017.0         1280.0    GasA         Ex           Y
# 9           0.0        415.0         1595.0    GasA         Ex           Y
#
#   electrical  first_flr_sf  2nd_flr_sf  low_qual_fin_sf  gr_liv_area  \
#
# 1      SBrkr          1656           0                0         1656
# 3      SBrkr          1329           0                0         1329
# 5      SBrkr           928         701                0         1629
# 8      SBrkr          1280           0                0         1280
# 9      SBrkr          1616           0                0         1616
#
#    bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  bedroom_abvgr  \
#
# 1             1.0             0.0          1          0              3
# 3             0.0             0.0          1          1              3
# 5             0.0             0.0          2          1              3
# 8             0.0             0.0          2          0              2
# 9             1.0             0.0          2          0              2
#
#    kitchen_abvgr kitchen_qual  totrms_abvgrd functional  fireplaces  \
#
# 1              1           TA              7        Typ           2
# 3              1           Gd              6        Typ           0
# 5              1           TA              6        Typ           1
# 8              1           Gd              5        Typ           0
# 9              1           Gd              5        Typ           1
#
#   fireplace_qu garage_type  garage_yr_blt garage_finish  garage_cars  \
#
# 1           Gd      Attchd         1960.0           Fin          2.0
# 3          NaN      Attchd         1958.0           Unf          1.0
# 5           TA      Attchd         1997.0           Fin          2.0
# 8          NaN      Attchd         1992.0           RFn          2.0
# 9           TA      Attchd         1995.0           RFn          2.0
#
#    garage_area garage_qual garage_cond paved_drive  wood_deck_sf  \
#
# 1        528.0          TA          TA           P           210
# 3        312.0          TA          TA           Y           393
# 5        482.0          TA          TA           Y           212
# 8        506.0          TA          TA           Y             0
# 9        608.0          TA          TA           Y           237
#
#    open_porch_sf  enclosed_porch  threessn_porch  screen_porch  pool_area  \
#
# 1             62               0               0             0          0
# 3             36               0               0             0          0
# 5             34               0               0             0          0
# 8             82               0               0           144          0
# 9            152               0               0             0          0
#
#   pool_qc  fence misc_feature  misc_val  mo_sold  yr_sold sale_type  saleprice
#
# 1     NaN    NaN          NaN         0        5     2010       WD      215000
# 3     NaN    NaN         Gar2     12500        6     2010       WD      172000
# 5     NaN  MnPrv          NaN         0        3     2010       WD      189900
# 8     NaN    NaN          NaN         0        1     2010       WD      191500
# 9     NaN    NaN          NaN         0        3     2010       WD      236500

# %%
# COLUMN:		lot_area
# DEFINITION:	Lot size in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.lot_area.unique()
# EVALUATION: COLUMN READY TO GO... DATA TYPE GOOD, NO MISSING VALUES!
# Out:
# array([31770, 14267, 13830, ..., 17400,  7937,  8885])

# %%
# COLUMN:		alley
# DEFINITION:	Alley: Type of alley access to property
# DATA TYPE:	object
# MISSING VALUES:	1911
# UNIQUE VALUES:	
df.alley.unique()
# EVALUATION:COLUMN WHERE THERE IS ONE POINT OF ENTRY, COULD EFFECT PRICE. MISSING DATA CAUSE LOT DOESN'T ABUTT ALLEY.
# CHANGED DATA TO REFLECT WHETHER LOT HAS ALLEY.
# Out:
# array([nan, 'Pave', 'Grvl'], dtype=object)

# %%
alley = {np.nan:'0', 'Pave':'1', 'Grvl':'1'}

# %%
alley = {np.nan:'0', 'Pave':'1', 'Grvl':'1'}
alley = [alley[item] for item in df.alley] 
df["alley"] = alley.astype(dtype=np.int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-3019682ca950> in <module>
#       1 alley = {np.nan:'0', 'Pave':'1', 'Grvl':'1'}
#       2 alley = [alley[item] for item in df.alley]
# ----> 3 df["alley"] = alley.astype(dtype=np.int)
#
# AttributeError: 'list' object has no attribute 'astype'

# %%
df['alley'].dtype
# Out:
# dtype('O')

# %%
df.alley.unique()
# Out:
# array([nan, 'Pave', 'Grvl'], dtype=object)

# %%
df.head(5)
# Out:
#    ms_subclass  ms_zoning  lot_area street  alley land_contour utilities  \
#
# 1           20          0     31770   Pave      0          Lvl    AllPub
# 3           20          0     14267   Pave      0          Lvl    AllPub
# 5           60          0     13830   Pave      0          Lvl    AllPub
# 8          120          0      5005   Pave      0          HLS    AllPub
# 9          120          0      5389   Pave      0          Lvl    AllPub
#
#   lot_config land_slope neighborhood condition_1 condition_2 bldg_type  \
#
# 1     Corner        Gtl        NAmes        Norm        Norm      1Fam
# 3     Corner        Gtl        NAmes        Norm        Norm      1Fam
# 5     Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 8     Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
# 9     Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
#
#   house_style  overall_qual  overall_cond  year_built  year_remod_add  \
#
# 1      1Story             6             5        1960            1960
# 3      1Story             6             6        1958            1958
# 5      2Story             5             5        1997            1998
# 8      1Story             8             5        1992            1992
# 9      1Story             8             5        1995            1996
#
#   roof_style roof_matl exterior_first exterior_2nd mas_vnr_type  mas_vnr_area  \
#
# 1        Hip   CompShg        BrkFace      Plywood        Stone         112.0
# 3        Hip   CompShg        Wd Sdng      Wd Sdng      BrkFace         108.0
# 5      Gable   CompShg        VinylSd      VinylSd         None           0.0
# 8      Gable   CompShg        HdBoard      HdBoard         None           0.0
# 9      Gable   CompShg        CemntBd      CmentBd         None           0.0
#
#   exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
#
# 1         TA         TA     CBlock        TA        Gd            Gd
# 3         TA         TA     CBlock        TA        TA            No
# 5         TA         TA      PConc        Gd        TA            No
# 8         Gd         TA      PConc        Gd        TA            No
# 9         Gd         TA      PConc        Gd        TA            No
#
#   bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
#
# 1            BLQ         639.0            Unf           0.0        441.0
# 3            ALQ         923.0            Unf           0.0        406.0
# 5            GLQ         791.0            Unf           0.0        137.0
# 8            ALQ         263.0            Unf           0.0       1017.0
# 9            GLQ        1180.0            Unf           0.0        415.0
#
#    total_bsmt_sf heating heating_qc central_air electrical  first_flr_sf  \
#
# 1         1080.0    GasA         Fa           Y      SBrkr          1656
# 3         1329.0    GasA         TA           Y      SBrkr          1329
# 5          928.0    GasA         Gd           Y      SBrkr           928
# 8         1280.0    GasA         Ex           Y      SBrkr          1280
# 9         1595.0    GasA         Ex           Y      SBrkr          1616
#
#    2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  \
#
# 1           0                0         1656             1.0             0.0
# 3           0                0         1329             0.0             0.0
# 5         701                0         1629             0.0             0.0
# 8           0                0         1280             0.0             0.0
# 9           0                0         1616             1.0             0.0
#
#    full_bath  half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  \
#
# 1          1          0              3              1           TA
# 3          1          1              3              1           Gd
# 5          2          1              3              1           TA
# 8          2          0              2              1           Gd
# 9          2          0              2              1           Gd
#
#    totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
#
# 1              7        Typ           2           Gd      Attchd
# 3              6        Typ           0          NaN      Attchd
# 5              6        Typ           1           TA      Attchd
# 8              5        Typ           0          NaN      Attchd
# 9              5        Typ           1           TA      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
#
# 1         1960.0           Fin          2.0        528.0          TA
# 3         1958.0           Unf          1.0        312.0          TA
# 5         1997.0           Fin          2.0        482.0          TA
# 8         1992.0           RFn          2.0        506.0          TA
# 9         1995.0           RFn          2.0        608.0          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
#
# 1          TA           P           210             62               0
# 3          TA           Y           393             36               0
# 5          TA           Y           212             34               0
# 8          TA           Y             0             82               0
# 9          TA           Y           237            152               0
#
#    threessn_porch  screen_porch  pool_area pool_qc  fence misc_feature  \
#
# 1               0             0          0     NaN    NaN          NaN
# 3               0             0          0     NaN    NaN         Gar2
# 5               0             0          0     NaN  MnPrv          NaN
# 8               0           144          0     NaN    NaN          NaN
# 9               0             0          0     NaN    NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type  saleprice
#
# 1         0        5     2010       WD      215000
# 3     12500        6     2010       WD      172000
# 5         0        3     2010       WD      189900
# 8         0        1     2010       WD      191500
# 9         0        3     2010       WD      236500

# %%
# COLUMN:		lot_shape
# DEFINITION:	General shape of property
# DATA TYPE:	object
# MISSING VALUES:	1911
# UNIQUE VALUES:	
df.lot_shape.unique()
# EVALUATION: COLUMN DOES NOT PERTAIN TO HOUSING PRICE, MISSING VALUES, COLUMN TO BE DROPPED!
# Out:
# array(['IR1', 'Reg', 'IR2', 'IR3'], dtype=object)

# %%
df=df.drop(columns=['lot_shape'])

# %%
df.head(5)
# Out:
#    ms_subclass  ms_zoning  lot_area street  alley land_contour utilities  \
#
# 1           20          0     31770   Pave      0          Lvl    AllPub
# 3           20          0     14267   Pave      0          Lvl    AllPub
# 5           60          0     13830   Pave      0          Lvl    AllPub
# 8          120          0      5005   Pave      0          HLS    AllPub
# 9          120          0      5389   Pave      0          Lvl    AllPub
#
#   lot_config land_slope neighborhood condition_1 condition_2 bldg_type  \
#
# 1     Corner        Gtl        NAmes        Norm        Norm      1Fam
# 3     Corner        Gtl        NAmes        Norm        Norm      1Fam
# 5     Inside        Gtl      Gilbert        Norm        Norm      1Fam
# 8     Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
# 9     Inside        Gtl      StoneBr        Norm        Norm    TwnhsE
#
#   house_style  overall_qual  overall_cond  year_built  year_remod_add  \
#
# 1      1Story             6             5        1960            1960
# 3      1Story             6             6        1958            1958
# 5      2Story             5             5        1997            1998
# 8      1Story             8             5        1992            1992
# 9      1Story             8             5        1995            1996
#
#   roof_style roof_matl exterior_first exterior_2nd mas_vnr_type  mas_vnr_area  \
#
# 1        Hip   CompShg        BrkFace      Plywood        Stone         112.0
# 3        Hip   CompShg        Wd Sdng      Wd Sdng      BrkFace         108.0
# 5      Gable   CompShg        VinylSd      VinylSd         None           0.0
# 8      Gable   CompShg        HdBoard      HdBoard         None           0.0
# 9      Gable   CompShg        CemntBd      CmentBd         None           0.0
#
#   exter_qual exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure  \
#
# 1         TA         TA     CBlock        TA        Gd            Gd
# 3         TA         TA     CBlock        TA        TA            No
# 5         TA         TA      PConc        Gd        TA            No
# 8         Gd         TA      PConc        Gd        TA            No
# 9         Gd         TA      PConc        Gd        TA            No
#
#   bsmtfin_type_1  bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  \
#
# 1            BLQ         639.0            Unf           0.0        441.0
# 3            ALQ         923.0            Unf           0.0        406.0
# 5            GLQ         791.0            Unf           0.0        137.0
# 8            ALQ         263.0            Unf           0.0       1017.0
# 9            GLQ        1180.0            Unf           0.0        415.0
#
#    total_bsmt_sf heating heating_qc central_air electrical  first_flr_sf  \
#
# 1         1080.0    GasA         Fa           Y      SBrkr          1656
# 3         1329.0    GasA         TA           Y      SBrkr          1329
# 5          928.0    GasA         Gd           Y      SBrkr           928
# 8         1280.0    GasA         Ex           Y      SBrkr          1280
# 9         1595.0    GasA         Ex           Y      SBrkr          1616
#
#    2nd_flr_sf  low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  \
#
# 1           0                0         1656             1.0             0.0
# 3           0                0         1329             0.0             0.0
# 5         701                0         1629             0.0             0.0
# 8           0                0         1280             0.0             0.0
# 9           0                0         1616             1.0             0.0
#
#    full_bath  half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  \
#
# 1          1          0              3              1           TA
# 3          1          1              3              1           Gd
# 5          2          1              3              1           TA
# 8          2          0              2              1           Gd
# 9          2          0              2              1           Gd
#
#    totrms_abvgrd functional  fireplaces fireplace_qu garage_type  \
#
# 1              7        Typ           2           Gd      Attchd
# 3              6        Typ           0          NaN      Attchd
# 5              6        Typ           1           TA      Attchd
# 8              5        Typ           0          NaN      Attchd
# 9              5        Typ           1           TA      Attchd
#
#    garage_yr_blt garage_finish  garage_cars  garage_area garage_qual  \
#
# 1         1960.0           Fin          2.0        528.0          TA
# 3         1958.0           Unf          1.0        312.0          TA
# 5         1997.0           Fin          2.0        482.0          TA
# 8         1992.0           RFn          2.0        506.0          TA
# 9         1995.0           RFn          2.0        608.0          TA
#
#   garage_cond paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  \
#
# 1          TA           P           210             62               0
# 3          TA           Y           393             36               0
# 5          TA           Y           212             34               0
# 8          TA           Y             0             82               0
# 9          TA           Y           237            152               0
#
#    threessn_porch  screen_porch  pool_area pool_qc  fence misc_feature  \
#
# 1               0             0          0     NaN    NaN          NaN
# 3               0             0          0     NaN    NaN         Gar2
# 5               0             0          0     NaN  MnPrv          NaN
# 8               0           144          0     NaN    NaN          NaN
# 9               0             0          0     NaN    NaN          NaN
#
#    misc_val  mo_sold  yr_sold sale_type  saleprice
#
# 1         0        5     2010       WD      215000
# 3     12500        6     2010       WD      172000
# 5         0        3     2010       WD      189900
# 8         0        1     2010       WD      191500
# 9         0        3     2010       WD      236500

# %%
# COLUMN:		land_contour
# DEFINITION:	Land Contour: Flatness of the property
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.land_contour.unique()
# Out:
# array(['Lvl', 'HLS', 'Bnk', 'Low'], dtype=object)

# %%
# COLUMN:		utilities
# DEFINITION:	Type of utilities available
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.utilities.unique()
# Out:
# array(['AllPub', 'NoSewr', 'NoSeWa'], dtype=object)

# %%
# COLUMN:		lot_config
# DEFINITION:	Type of utilities available
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.lot_config.unique()
# Out:
# array(['Corner', 'Inside', 'CulDSac', 'FR2', 'FR3'], dtype=object)

# %%
# COLUMN:		lot_config
# DEFINITION:	 Lot configuration
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.lot_config.unique()
# Out:
# array(['Corner', 'Inside', 'CulDSac', 'FR2', 'FR3'], dtype=object)

# %%
# COLUMN:		land_slope
# DEFINITION:	Slope of property
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.land_slope.unique()
# Out:
# array(['Gtl', 'Mod', 'Sev'], dtype=object)

# %%
# COLUMN:		neighborhood
# DEFINITION:	Physical locations within Ames city limits
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.neighborhood.unique()
# Out:
# array(['NAmes', 'Gilbert', 'StoneBr', 'NWAmes', 'Somerst', 'BrDale',
#        'NPkVill', 'NridgHt', 'Blmngtn', 'NoRidge', 'SawyerW', 'Sawyer',
#        'Greens', 'BrkSide', 'OldTown', 'IDOTRR', 'ClearCr', 'SWISU',
#        'Edwards', 'CollgCr', 'Crawfor', 'Blueste', 'Mitchel', 'Timber',
#        'MeadowV', 'Veenker', 'GrnHill', 'Landmrk'], dtype=object)

# %%
# COLUMN:		condition_1
# DEFINITION:	Proximity to various conditions
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. condition_1.unique()
# Out:
# array(['Norm', 'RRAe', 'RRNe', 'Feedr', 'Artery', 'PosA', 'PosN', 'RRAn',
#        'RRNn'], dtype=object)

# %%
# COLUMN:		condition_2
# DEFINITION:	Proximity to various conditions (if more than one is present)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.condition_2.unique()
# Out:
# array(['Norm', 'Feedr', 'PosN', 'Artery', 'PosA', 'RRNn', 'RRAe', 'RRAn'],
#       dtype=object)

# %%
# COLUMN:		bldg_type
# DEFINITION:	Type of dwelling
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.bldg_type.unique()
# Out:
# array(['1Fam', 'TwnhsE', 'Twnhs', 'Duplex', '2fmCon'], dtype=object)

# %%
# COLUMN:		house_style 
# DEFINITION:	Style of dwelling
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.house_style.unique()
# Out:
# array(['1Story', '2Story', 'SLvl', '1.5Fin', 'SFoyer', '2.5Unf', '1.5Unf',
#        '2.5Fin'], dtype=object)

# %%
# COLUMN:		overall_qual
# DEFINITION:	Rates the overall material and finish of the house
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.overall_qual.unique()
# Out:
# array([ 6,  5,  8,  7,  4,  9,  3,  2, 10,  1])

# %%
# COLUMN:		overall_cond        
# DEFINITION:	Rates the overall condition of the house
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. overall_cond.unique()
# Out:
# array([5, 6, 7, 8, 2, 4, 9, 3, 1])

# %%
# COLUMN:		year_built
# DEFINITION:	Original construction date
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.year_built.unique()
# Out:
# array([1960, 1958, 1997, 1992, 1995, 1999, 1993, 1998, 1990, 1985, 2003,
#        1951, 1978, 1977, 2000, 1970, 1971, 1968, 1975, 2009, 2007, 2005,
#        2004, 2002, 2006, 2001, 1996, 1994, 2008, 1980, 1979, 1984, 1965,
#        1967, 1962, 1974, 2010, 1976, 1988, 1963, 1959, 1966, 1964, 1949,
#        1940, 1954, 1955, 1956, 1953, 1920, 1948, 1952, 1927, 1957, 1945,
#        1929, 1923, 1928, 1900, 1915, 1910, 1885, 1922, 1950, 1939, 1942,
#        1936, 1930, 1921, 1912, 1875, 1969, 1947, 1946, 1987, 1941, 1924,
#        1989, 1896, 1991, 1972, 1981, 1973, 1961, 1916, 1925, 1890, 1935,
#        1938, 1898, 1917, 1937, 1926, 1931, 1934, 1983, 1880, 1932, 1986,
#        1905, 1914, 1872, 1893, 1911, 1895, 1982, 1879, 1901, 1918, 1913,
#        1908, 1892, 1919])

# %%
# COLUMN:		year_remod_add      
# DEFINITION:	Remodel date (same as construction date if no remodeling or additions)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.year_remod_add.unique()
# Out:
# array([1960, 1958, 1998, 1992, 1996, 1999, 1994, 2007, 1990, 1985, 2003,
#        1951, 1988, 1977, 2000, 1970, 2008, 1968, 1971, 1975, 2010, 2005,
#        2006, 2004, 2002, 2001, 1995, 2009, 1980, 1979, 1978, 1967, 1993,
#        1963, 1959, 1966, 1964, 1950, 1954, 1972, 1956, 1955, 1952, 1962,
#        1984, 1957, 1997, 1965, 1969, 1987, 1976, 1989, 1991, 1986, 1981,
#        1974, 1973, 1961, 1983, 1953, 1982])

# %%
# COLUMN:		roof_style         
# DEFINITION:	Type of roof
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.roof_style.unique()
# Out:
# array(['Hip', 'Gable', 'Mansard', 'Flat', 'Gambrel', 'Shed'], dtype=object)

# %%
# COLUMN:		roof_matl                  
# DEFINITION:	Roof material
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.roof_matl.unique()
# Out:
# array(['CompShg', 'WdShngl', 'Tar&Grv', 'WdShake', 'Membran', 'ClyTile'],
#       dtype=object)

# %%
# COLUMN:		exterior_1st                        
# DEFINITION:	Exterior covering on house
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exterior_first.unique()
# Out:
# array(['BrkFace', 'Wd Sdng', 'VinylSd', 'HdBoard', 'CemntBd', 'Plywood',
#        'MetalSd', 'AsbShng', 'WdShing', 'Stucco', 'BrkComm', 'CBlock',
#        'AsphShn', 'Stone', 'ImStucc'], dtype=object)

# %%
# COLUMN:		exterior_2nd                              
# DEFINITION:	Exterior covering on house (if more than one material)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. exterior_2nd.unique()
# Out:
# array(['Plywood', 'Wd Sdng', 'VinylSd', 'HdBoard', 'CmentBd', 'Wd Shng',
#        'MetalSd', 'ImStucc', 'Brk Cmn', 'AsbShng', 'BrkFace', 'Stucco',
#        'CBlock', 'Stone', 'AsphShn'], dtype=object)

# %%
# COLUMN:		mas_vnr_type                                     
# DEFINITION:	Masonry veneer type
# DATA TYPE:	object
# MISSING VALUES:	22
# UNIQUE VALUES:	
df.mas_vnr_type.unique()
# Out:
# array(['Stone', 'BrkFace', 'None', nan, 'BrkCmn'], dtype=object)

# %%
# COLUMN:		mas_vnr_area                                          
# DEFINITION:	Masonry veneer area in square feet
# DATA TYPE:	float64
# MISSING VALUES:	22
# UNIQUE VALUES:	
df.mas_vnr_area.unique()
# Out:
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exter_qual.unique()
# Out:
# array(['TA', 'Gd', 'Ex', 'Fa'], dtype=object)

# %%
# COLUMN:		exter_cond                                                           
# DEFINITION:	Evaluates the present condition of the material on the exterior
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.exter_cond.unique()
# Out:
# array(['TA', 'Gd', 'Po', 'Fa', 'Ex'], dtype=object)

# %%
# COLUMN:		foundation                                                                    
# DEFINITION:	Type of foundation
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.foundation.unique()
# Out:
# array(['CBlock', 'PConc', 'Slab', 'BrkTil', 'Stone', 'Wood'], dtype=object)

# %%
# COLUMN:		bsmt_qual                                                                              
# DEFINITION:	Evaluates the height of the basement
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df. bsmt_qual.unique()
# Out:
# array(['TA', 'Gd', 'Ex', nan, 'Fa', 'Po'], dtype=object)

# %%
# COLUMN:		bsmt_cond                                                                                        
# DEFINITION:	Evaluates the general condition of the basement
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df.bsmt_cond.unique()
# Out:
# array(['Gd', 'TA', nan, 'Po', 'Fa', 'Ex'], dtype=object)

# %%
# COLUMN:		bsmt_exposure                                                                                              
# DEFINITION:	Refers to walkout or garden level walls
# DATA TYPE:	object
# MISSING VALUES:	58
# UNIQUE VALUES:	
df.bsmt_exposure.unique()
# Out:
# array(['Gd', 'No', 'Av', 'Mn', nan], dtype=object)

# %%
# COLUMN:		bsmtfin_type_1                                                                                                   
# DEFINITION:	Rating of basement finished areawalls
# DATA TYPE:	object
# MISSING VALUES:	55
# UNIQUE VALUES:	
df.bsmtfin_type_1.unique()
# Out:
# array(['BLQ', 'ALQ', 'GLQ', 'Unf', 'LwQ', 'Rec', nan], dtype=object)

# %%
# COLUMN:		bsmtfin_sf_1                                                                                                        
# DEFINITION:	Type 1 finished square feet
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmtfin_sf_1.unique()
# Out:
# array([6.390e+02, 9.230e+02, 7.910e+02, 2.630e+02, 1.180e+03, 0.000e+00,
#        9.350e+02, 6.370e+02, 3.680e+02, 1.416e+03, 1.200e+02, 7.900e+02,
#        7.050e+02, 5.330e+02, 5.780e+02, 7.340e+02, 7.750e+02, 4.320e+02,
#        1.051e+03, 1.560e+02, 3.600e+02, 5.140e+02, 1.218e+03, 1.201e+03,
#        2.800e+01, 2.000e+00, 2.188e+03, 1.373e+03, 4.560e+02, 2.400e+01,
#        3.260e+02, 6.250e+02, 9.190e+02, 1.032e+03, 5.240e+02, 8.160e+02,
#        1.078e+03, 2.220e+02, 6.560e+02, 6.950e+02, 5.430e+02, 3.380e+02,
#        5.530e+02, 4.500e+02, 6.590e+02, 1.260e+02, 6.740e+02, 1.298e+03,
#        2.800e+02, 3.760e+02, 3.780e+02, 2.440e+02, 1.052e+03, 5.060e+02,
#        1.137e+03, 1.200e+03, 3.940e+02, 5.690e+02, 1.059e+03, 1.010e+03,
#        4.750e+02, 1.670e+02, 6.910e+02, 4.240e+02, 3.050e+02, 2.160e+02,
#        2.230e+02, 5.260e+02, 2.960e+02, 1.573e+03, 1.564e+03, 5.760e+02,
#        9.090e+02, 1.053e+03, 1.136e+03, 1.274e+03, 1.455e+03, 1.243e+03,
#        8.970e+02, 8.370e+02, 1.490e+02, 1.606e+03, 3.010e+02, 1.071e+03])

# %%
# COLUMN:		bsmtfin_type_2                                                                                                             
# DEFINITION:	Rating of basement finished area (if multiple types)
# DATA TYPE:	object
# MISSING VALUES:	56
# UNIQUE VALUES:	
df.bsmtfin_type_2.unique()
# Out:
# array(['Unf', 'BLQ', 'Rec', nan, 'GLQ', 'ALQ', 'LwQ'], dtype=object)

# %%
# COLUMN:		bsmtfin_sf_2                                                                                                                   
# DEFINITION:	Type 2 finished square feet
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmtfin_sf_2.unique()
# Out:
# array([   0., 1120.,  163.,  119.,  117.,  859.,   42.,   81.,  290.,
#         132.,  713.,  162.,  258.,  174.,  906.,  486.,  263., 1073.,
#         692.,   12.,  159.,  474.,  387.,  688.,  712.,  127.,  334.,
#         232.,  590.,  284.,  168.,  239.,  294.,  622.,  495.,  539.,
#         479.,  113.,  180.,  774.,  364.,  596.,  311.,   92.,  147.,
#        1127.,  466.,  201.,  345.,  230.,  247.,  661.,  620.,  202.,
#         483.,  750.,  105.,   60.,  102.,   95.,  465.,  262.,  500.,
#         670.,  768.,  286.,  450.,  177.,  344.,   72.,  144.,  420.,
#         210.,  875.,  507.,  419.,  116.,  354.,  624.,  273.,   76.,
#         270.,  110.,  288.,  411.,  276.,  228.,  186.,   93.,  613.,
#         852.,  555.,  811.,  842.,  382.,  182.,   80.,   64.,  306.,
#         308.,  374.,  872.,  108.,   52.,  196.,  128.,  488.,  532.,
#         106.,  169.,  608.,   nan,  240.,   41.,  645.,  181.,  956.,
#        1080., 1063.,  380.,  531.,  435.,  120.,  612.,  125.,  400.,
#         208.,  823.,  121.,  175.,  604.,   35.,  619.,    6.,  351.,
#        1037.,  829.,  211.,  264.,   38.,  279.,  206.,  167.,  580.,
#         219.,  259.,  404.,  723.,  138.,  955.,   66.,   96.,  149.,
#         154.,  442.,  227.,  546.,  469.,  722.,  761.,  529.,  522.,
#         891., 1474.,  321.,  915.,  417.,  432.,  468.,  841.,  278.,
#         557.,  150.,  869.,  499.,  215., 1061.,  377.,  156.,  492.,
#        1393., 1039.,  375.,  497., 1057.,  526.,   68.,  252.,  748.,
#          28.,  281.,  600.,  506.,  373.,  551.,  982.,  441., 1085.,
#         850., 1083.,  297.,  547.,   40.,  173.,  324.,  123.])

# %%
# COLUMN:		bsmt_unf_sf                                                                                                                         
# DEFINITION:	Unfinished square feet of basement area
# DATA TYPE:	float64
# MISSING VALUES:	1
# UNIQUE VALUES:	
df.bsmt_unf_sf.unique()
# Out:
# array([ 441.,  406.,  137., 1017.,  415.,  994.,  763.,  233.,  789.,
#         959., 1396., 1733., 1165., 1286., 1095., 1257., 1293., 1400.,
#         891.,  636.,  506., 1748., 1334., 1624., 1247.,  673., 1842.,
#        1051., 1251., 2136., 1106., 1058., 1070.,  216., 1015., 2171.,
#         617., 1083.,  655., 1438., 1025.,  502.,  492.,  815., 1020.,
#        1103.,  485.,  693.,  596.,  396.,  610., 1007., 1062.,  830.,
#        1059., 1763.,  648., 1000.,  430.,  697., 1199., 1570., 1533.,
#        1525.,  842.,  826., 1860., 1552.,  658.,  954.,  498.,  818.,
#         792.,  700.,  432., 1664., 1491., 1907., 1112., 1309., 1381.,
#         757., 1003.])

# %%
# COLUMN:		heating                                                                                                                                         
# DEFINITION:	Type of heating
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.heating.unique()
# Out:
# array(['GasA', 'GasW', 'Grav', 'Wall', 'OthW'], dtype=object)

# %%
# COLUMN:		heating_qc                                                                                                                                                  
# DEFINITION:	Heating quality and condition
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.heating_qc.unique()
# Out:
# array(['Fa', 'TA', 'Gd', 'Ex', 'Po'], dtype=object)

# %%
# COLUMN:		central_air                                                                                                                                                          
# DEFINITION:	Central air conditioning
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.central_air.unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
# COLUMN:		electrical                                                                                                                                                                   
# DEFINITION:	Electrical system
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. electrical.unique()
# Out:
# array(['SBrkr', 'FuseA', 'FuseF', 'FuseP', 'Mix'], dtype=object)

# %%
# COLUMN:		1st_flr_sf                                                                                                                                                                                     
# DEFINITION:	First Floor square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.first_flr_sf.unique()
# Out:
# array([1656, 1329,  928, 1280, 1616, 1028,  763, 1187,  789, 1341, 1502,
#        1690,  864, 2073, 1844,  814, 1004, 1078, 1056, 1337,  483,  525,
#        1069,  855,  836, 1627, 1704, 1541, 1822, 1535, 2364, 2696, 1687,
#        1752, 1370,  764, 1324, 1269,  744,  860,  847,  884, 1422, 1720,
#        1500, 1164, 1195, 2053, 1595, 1218, 1566,  991,  956,  831, 1222,
#         923, 1055,  918, 1097, 1318,  894,  900, 1040, 1494, 1061, 1488,
#         600, 1478,  769,  530, 1418, 1226,  725, 1829, 1610,  980, 1328,
#        1225, 1209, 1510, 1131, 1152, 1019,  858, 1306, 1063, 1520, 1105,
#        1888, 1604, 1480, 1143, 1700, 1194, 1188, 1264,  832,  972,  988,
#        1057,  985,  827,  912, 1287,  816, 1246,  910, 1116, 1395, 1051,
#         936, 1347,  747,  804,  926, 1027,  720,  930,  966, 1128, 1236,
#         741,  868, 1030,  608,  848,  955,  780,  548, 1068,  902,  888,
#         662,  372, 1207, 1768, 1039, 1392,  892,  663, 1373, 1483,  756,
#        1067, 1117,  835, 1074, 1169, 1172, 1508, 1298,  977, 1433,  964,
#        1062,  996, 1694, 1208, 1699, 1026, 1978, 1601, 1661, 1484, 1414,
#         640,  992, 1196,  792, 1096,  960, 1121,  798,  672, 1296,  841,
#        1902,  896, 1034, 1191, 1801,  796,  540,  698,  859, 1044,  952,
#        1646, 1036, 1285, 1560, 2048, 1346, 1214,  774,  824,  993, 1430,
#         536,  546,  874,  833,  624, 1803, 2000,  945, 1008, 1746, 1659,
#         788, 1035, 1054, 1073, 1258, 1228, 1721, 1291, 1156, 1524, 1363,
#        1663, 1357,  617,  820,  616, 1532, 1093, 1626,  628, 2276, 1511,
#        1099,  782,  963, 1174, 1076, 1558,  924, 1795, 1366, 1786, 1129,
#        1838, 1536,  770, 1564, 1361, 1033, 1127, 1181,  760, 3820, 4692,
#        1440, 1390, 1424, 1024, 1423,  790,  851,  849,  983, 1137, 1898,
#        1640,  778, 1151,  733,  649, 2032, 1118, 2898,  920,  712, 1495,
#        1651, 1509, 1964, 1189,  845,  889, 1587, 2223, 2217,  806,  957,
#        1179, 1321, 1922, 2338, 1612, 2042, 1140, 1664, 1161, 1353,  576,
#         981,  958, 1828, 2122, 2121, 2046, 1071, 1973, 1634, 1976, 1722,
#        2290, 1582, 1802,  895, 1614, 1554, 1577, 1326,  752, 1589, 1525,
#         953,  940,  997, 2633, 1411, 3228, 1335, 1905, 1534, 1636, 1528,
#        1538, 1184, 1685, 1094, 1349,  970, 1696, 1701, 2129, 1565, 1352,
#        1550, 1241,  625,  551,  975, 1437, 1262, 2497, 1594, 1242, 1107,
#        1042, 1429,  908,  334,  666, 1150,  968, 1465,  922, 1657, 1647,
#         735, 1238,  967,  679, 1178, 1149, 1559,  915,  939,  959,  933,
#         969, 1497,  838,  581, 1452, 1029,  943, 1416, 1522, 2158,  605,
#        1553, 1282, 2140, 1482, 1274, 1546, 1270,  879, 1079,  905,  853,
#        1009, 1673, 1592, 5095,  740,  759,  567,  686,  661,  954,  867,
#        1230, 2259,  529, 2515, 2726,  803,  772,  942, 1409, 2034, 1622,
#        1060, 1356,  887, 1293, 1851,  781, 1670, 2079, 1102, 1992, 1850,
#        1426, 1547, 1872, 1083, 1109, 1309,  494, 1387, 1980, 1738, 1249,
#        2076, 1740, 1868, 1132, 1038, 1625, 1792, 1666, 1557, 1456, 1248,
#         734,  807, 1454, 1407, 1205, 1086, 1933, 1203, 1278, 1400,  891,
#         844, 1398,  636, 1211,  935, 2151, 1624, 1247,  673, 1842, 1193,
#        2156, 1012,  898, 2136, 1235, 1190, 1124,  865,  715,  448, 1900,
#        1556, 1025, 1007,  502,  714,  492,  815, 1103,  693,  834,  665,
#        1320, 1059, 1159, 1458, 1779, 1000, 1304, 1065, 1590,  795,  856,
#        1787, 1070, 1552,  750,  846,  658,  949,  498, 1058,  743,  818,
#         961, 1811,  897,  480, 1778, 1491, 1959, 1295, 1650, 1339, 1403,
#        1003, 1389])

# %%
# COLUMN:		low_qual_fin_sf              
# DEFINITION:	Low quality finished square feet (all floors)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.low_qual_fin_sf.unique()
# Out:
# array([   0,  390,  362,  144, 1064,  120,  436,  371,  259,  397,  312,
#         513,  108,  205,  156,  697,  384,  473,  512,  528,  114,  479,
#         515,   53,   80,  572,  360,  234,  140,  450,  514])

# %%
# COLUMN:		gr_liv_area                       
# DEFINITION:	Above grade (ground) living area square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.gr_liv_area.unique()
# Out:
# array([1656, 1329, 1629, ..., 1003, 1389, 2000])

# %%
# COLUMN:		bsmt_full_bath                           
# DEFINITION:	Basement full bathrooms
# DATA TYPE:	float64
# MISSING VALUES:	2
# UNIQUE VALUES:	
df.bsmt_full_bath.unique()
# Out:
# array([ 1.,  0.,  2.,  3., nan])

# %%
# COLUMN:		bsmt_half_bath                              
# DEFINITION:	Basement half bathrooms
# DATA TYPE:	float64
# MISSING VALUES:	2
# UNIQUE VALUES:	
df.bsmt_half_bath.unique()
# Out:
# array([ 0.,  1., nan,  2.])

# %%
# COLUMN:		full_bath                                        
# DEFINITION:	Full bathrooms above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.full_bath.unique()
# Out:
# array([1, 2, 3, 0, 4])

# %%
# COLUMN:		half_bath                                                  
# DEFINITION:	Half baths above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.half_bath.unique()
# Out:
# array([0, 1, 2])

# %%
# COLUMN:		bedroom_abvgr                                                  
# DEFINITION:	Bedrooms above grade (does NOT include basement bedrooms)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.bedroom_abvgr.unique()
# Out:
# array([3, 2, 1, 4, 5, 6, 0, 8])

# %%
# COLUMN:		kitchen_abvgr                                                        
# DEFINITION:	Kitchens above grade
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df. kitchen_abvgr.unique()
# Out:
# array([1, 2, 3, 0])

# %%
# COLUMN:		kitchen_qual                                                              
# DEFINITION:	Kitchen quality
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.kitchen_qual.unique()
# Out:
# array(['TA', 'Gd', 'Ex', 'Fa'], dtype=object)

# %%
# COLUMN:		totrms_abvgrd                                                                     
# DEFINITION:	Total rooms above grade (does not include bathrooms)
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.totrms_abvgrd.unique()
# Out:
# array([ 7,  6,  5,  4, 12, 10,  8, 11,  9,  3, 13,  2, 15, 14])

# %%
# COLUMN:		functional                                                                             
# DEFINITION:	Home functionality (Assume typical unless deductions are warranted)
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.functional.unique()
# Out:
# array(['Typ', 'Mod', 'Min1', 'Min2', 'Maj1', 'Maj2', 'Sev', 'Sal'],
#       dtype=object)

# %%
# COLUMN:		fireplaces                                                                                       
# DEFINITION:	Number of fireplaces
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.fireplaces.unique()
# Out:
# array([2, 0, 1, 3, 4])

# %%
# COLUMN:		fireplace_qu                                                                                              
# DEFINITION:	Fireplace quality
# DATA TYPE:	object
# MISSING VALUES:	1000
# UNIQUE VALUES:	
df.fireplace_qu.unique()
# Out:
# array(['Gd', nan, 'TA', 'Po', 'Fa', 'Ex'], dtype=object)

# %%
# COLUMN:		garage_type                                                                                                      
# DEFINITION:	Garage location
# DATA TYPE:	object
# MISSING VALUES:	113
# UNIQUE VALUES:	
df.garage_type.unique()
# Out:
# array(['Attchd', 'BuiltIn', 'Detchd', nan, 'Basment', '2Types', 'CarPort'],
#       dtype=object)

# %%
# COLUMN:		garage_yr_blt                                                                                                           
# DEFINITION:	Year garage was built
# DATA TYPE:	float64
# MISSING VALUES:	114
# UNIQUE VALUES:	
df.garage_yr_blt.unique()
# Out:
# array([1960., 1958., 1997., 1992., 1995., 1999., 1993., 1998., 1990.,
#        1985., 2003., 1951., 1978., 1977., 2000., 1970., 1971., 1968.,
#          nan, 1975., 2009., 2008., 2005., 2004., 2002., 2006., 2001.,
#        1996., 1994., 1980., 1979., 1986., 1973., 1962., 1974., 2010.,
#        1976., 1967., 1988., 1963., 1966., 1964., 1949., 1954., 1955.,
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.paved_drive.unique()
# Out:
# array(['P', 'Y', 'N'], dtype=object)

# %%
# COLUMN:		wood_deck_sf                                                                                                                                                       
# DEFINITION:	Wood deck area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.wood_deck_sf.unique()
# Out:
# array([ 210,  393,  212,    0,  237,  140,  157,  483,  192,  503,  349,
#         203,  275,  173,  144,  220,  238,  196,  120,   36,  146,  100,
#         288,  668,  240,  186,  132,  283,  169,   80,  635,   28,  416,
#         296,  168,  160,  223,  224,  228,  352,  227,  117,  263,   42,
#         252,  364,  414,  218,  222,  657,   51,  106,   54,  221,  306,
#          12,  344,   56,  379,  226,  496,  290,  336,  450,  156,  105,
#         367,  316,  365,  188,  180,   60,  257,  141,  112,   30,   68,
#         128,  375,  135,  182,  200,  431,   22,  287,  129,  162,  269,
#         201,   52,  256,  342,   63,  233,  474,   32,   96,  250,   87,
#         260,  108,  147,  216,  404,  382,  319,   99,  184,  125,  165,
#         248,  114,  230,  170,  172,  208,  148,  143,   24,  298,  340,
#         517,  297,   70,  205,  195,  158,  171,  462,  371,  312,  321,
#          78,   85,  164,  110,  289,  280,   66,  126,  187,   26,   40,
#          48,  266,   74,  244,   45,  189,  509,  302,  243,   64,  476,
#         328,   84,   73,  154,  185,  276,  392,  198,  150,   72,   58,
#         262,  202,  253,  115,  576,  356,  327,   92,  335,  136,  329,
#         400,  292,  467,  119,   90,  305,  308,   33,  138,  303,  264,
#         214,  152,  550,   16,  358,  320,  268,  495,  236,  385,  133,
#         277,  155,   97,  122,   98,   38,  355,   88,  418,  265,  272,
#          49,  204,  311,  178,  102,  409,   50,  307,   81,  424,  278,
#         211,  259,  736,  134,  121,  183,  161,  318,  428,  282,  315,
#         245,  300,  390,  167,  407,   35,  130,  124,  194,  314,  286,
#         255,  193,  159,  455,  500,  206,  113,  190,  235,  333,  284,
#         261,  225,  460,  239,  270,  116,   14,  521,  380,  646,  386,
#         370,  546,  118,  242,  291,  166,  174,  232,  439,  536, 1424,
#         104,  421,  441,  246,  324,  197,  384,  209,  444,  354,  519,
#         176,  142,  870,  309,  432,    4,  641,  177,  153,  857,   94,
#          86,  191,   75,  631,  229,  436,  345,  520,  394,   53,  466,
#         131,  241,  103,  586,  684,  413,  219,  406,  199,  207,  530,
#         123,  728,  295])

# %%
# COLUMN:		open_porch_sf                                                                                                                                                         
# DEFINITION:	Open porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.open_porch_sf.unique()
# Out:
# array([ 62,  36,  34,  82, 152,  60,  84,  21,  75,   0,  54, 122,  96,
#         85,  68,  55,  30, 133,  50,  70, 119,  67, 150, 130,  49,  27,
#         23,  20,  48,  56,  32,  57,  81,  86, 136,  45, 168, 104, 144,
#         39, 172, 166, 192,  78,  44,  76,  66,  26,  40,  73,  38,  52,
#         17, 124, 100, 228,  18, 158,  10,  11,  46, 278,  92,  90,  33,
#         61,  59,  25,  35, 105,  64, 140, 207,  53, 312, 111,  72,  94,
#        176, 195, 120,  28, 162, 102, 197,  98, 274, 170, 185, 190, 116,
#         63, 235, 183,  16,  51, 128, 146, 126, 165, 226, 121, 175, 113,
#         91,  41,  42,  93,  74, 234,  24,  99,  58,  88,  80, 110, 189,
#        204,  12, 156, 103, 523, 135, 198, 215, 142,  29, 151, 200, 148,
#        112, 160, 118, 154,  95, 238, 304, 101, 173,  22, 282,  69, 180,
#        134, 153,  87, 174, 108, 210, 251,  65, 243, 240, 211, 129,   4,
#        114, 213, 547, 291, 502, 299, 365, 182,  89, 117, 137,   8, 187,
#        155, 159, 106, 372, 292, 184, 141, 123, 276, 265, 164, 224, 205,
#        368,  47, 191, 364, 127, 256, 214, 241, 285, 324, 171,  15,  77,
#        244, 231, 484, 444, 252, 266,  97, 132,  37, 131, 208, 229,  43,
#         31, 169, 319, 138, 258, 341, 260, 288, 418, 236, 245, 107, 225,
#        125, 199])

# %%
# COLUMN:		enclosed_porch                                                                                                                                                              
# DEFINITION:	Enclosed porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.enclosed_porch.unique()
# Out:
# array([  0, 184, 154, 186, 156, 120, 150, 164, 189, 205, 113, 216, 135,
#        130, 126, 246, 196,  18, 158, 114, 128,  35,  48,  32,  64, 364,
#        112, 318,  45, 176,  77,  52,  56, 168,  36, 136, 162,  98, 265,
#         50, 280, 222, 202, 144,  24, 236,  84, 264, 260, 203, 140, 100,
#        134, 432, 198,  42,  40, 148,  25,  80, 160, 226, 244, 115,  94,
#        105,  54,  34, 268,  30, 213, 288,  90, 177, 211, 185, 180,  44,
#         57,  81, 218,  78,  72, 368,  70, 165,  92,  16, 192, 123,  96,
#        102,  66, 210, 109,  60, 194, 219, 259, 116, 212,  20, 101,  87,
#        117, 204, 122, 231, 239, 138, 301, 207, 224, 172, 174, 137,  99,
#        249, 252, 291, 145, 214, 275, 175,  26, 143, 183, 230, 170,  88,
#         39,  68,  43,  19, 200, 169, 133, 234,  37, 240, 324, 161,  75,
#        167, 104, 296, 330, 228, 256,  55, 129, 225, 294, 121, 190, 208,
#        272,  67,  23])

# %%
# COLUMN:		three_season_porch                                                                                                                                                                       
# DEFINITION:	Three season porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.threessn_porch.unique()
# Out:
# array([  0, 224, 144, 508, 168, 255, 162, 140, 150, 182, 153, 304, 407,
#         96, 245, 216, 120, 176,  86, 290, 180, 323])

# %%
# COLUMN:		screen_porch                                                                                                                                                                             
# DEFINITION:	Screen porch area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.screen_porch.unique()
# Out:
# array([  0, 144, 140, 210, 165, 204, 143, 182, 385, 240, 168, 148,  95,
#        266, 160, 161, 155, 291, 200, 490, 170, 192, 180, 156, 152, 288,
#        342, 189, 252, 216, 234, 255, 111, 112, 231, 120, 100, 142, 110,
#        396,  92, 195, 145, 224, 233, 190, 141, 208, 176, 196,  94, 164,
#        130, 480, 220,  64, 163,  90, 227, 265, 171, 135, 322, 174, 147,
#        276, 260, 175, 198, 217, 201, 109, 225, 150, 126, 259, 184,  84,
#        154, 116,  53, 153, 108,  88, 280, 440, 374, 222, 264, 270, 122,
#        162, 115, 410, 271, 312, 348, 113, 104, 138])

# %%
# COLUMN:		pool_area                                                                                                                                                                                       
# DEFINITION:	Pool area in square feet
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.pool_area.unique()
# Out:
# array([  0, 480, 576, 368, 228, 561, 519, 648, 800, 738])

# %%
# COLUMN:		pool_qc                                                                                                                                                                                                   
# DEFINITION:	Pool quality
# DATA TYPE:	object
# MISSING VALUES:	2042
# UNIQUE VALUES:	
df.pool_qc.unique()
# Out:
# array([nan, 'Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
# COLUMN:		fence              
# DEFINITION:	Fence quality
# DATA TYPE:	object
# MISSING VALUES:	1651
# UNIQUE VALUES:	
df.fence.unique()
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
# COLUMN:		misc_feature       
# DEFINITION:	Miscellaneous feature not covered in other categories
# DATA TYPE:	object
# MISSING VALUES:	1986
# UNIQUE VALUES:	
df.misc_feature.unique()
# Out:
# array([nan, 'Gar2', 'Shed', 'Othr', 'Elev', 'TenC'], dtype=object)

# %%
# COLUMN:		misc_val            
# DEFINITION:	$Value of miscellaneous feature
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.misc_val.unique()
# Out:
# array([    0, 12500,   500,   700,   400,   450,   300,  1200,  3500,
#         2000,  2500,    54,    80,   650,   600,   900,   800,  1500,
#         6500,  1150,  4500,  3000,  1300,  8300,   480, 17000,   455,
#          460])

# %%
# COLUMN:		mo_sold             
# DEFINITION:	Month Sold
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.mo_sold.unique()
# Out:
# array([ 5,  6,  3,  1,  4,  2,  7,  8, 10,  9, 12, 11])

# %%
# COLUMN:		yr_sold             
# DEFINITION:	Year Sold
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.yr_sold.unique()
# Out:
# array([2010, 2009, 2008, 2007, 2006])

# %%
# COLUMN:		sale_type          
# DEFINITION:	Type of sale
# DATA TYPE:	object
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.sale_type.unique()
# Out:
# array(['WD ', 'COD', 'ConLI', 'New', 'Con', 'ConLD', 'Oth', 'ConLw',
#        'CWD'], dtype=object)

# %%
# COLUMN:		saleprice                     
# DEFINITION:	Condition of sale
# DATA TYPE:	int64
# MISSING VALUES:	0
# UNIQUE VALUES:	
df.saleprice.unique()
# Out:
# array([215000, 172000, 189900, 191500, 236500, 189000, 175900, 185000,
#        180400, 171500, 212000, 538000, 141000, 210000, 190000, 216000,
#        149000, 149900, 142000, 115000, 184000,  96000,  88000, 127500,
#        120000, 376162, 306000, 220000, 259000, 214000, 611657, 500000,
#        320000, 319900, 205000, 175500, 199500, 192000, 184500, 216500,
#        185088, 222500, 333168, 260400, 325000, 290000, 221000, 410000,
#        221500, 204500, 215200, 262500, 254900, 233000, 181000, 143000,
#         99500, 152000, 112000, 138500, 122000, 127000, 169000, 260000,
#        155000, 151000, 149500, 222000, 177500, 147110, 267916, 206000,
#        130500, 218500, 243500, 196500, 128950, 159000, 178900, 136300,
#        180500, 172500, 116500,  76500, 128000, 153000, 154300, 135000,
#        136000, 165500, 148000, 167500, 108000, 122500, 119000, 109000,
#        105000, 107500,  97500, 162000, 132000, 154000, 166000, 134800,
#        160000, 109500,  80000, 130000, 129000,  12789, 105900, 150000,
#        139000, 149700, 125500, 140750, 128500, 134000, 139900, 123900,
#        138400, 140000, 159900,  55000, 244400,  95000,  94000, 136500,
#        131500, 121500, 125000, 137900, 158000, 137250, 160250, 328000,
#        134432, 109900, 108959, 149350, 144900, 152400, 241500, 125600,
#        262280, 229000, 177439, 475000, 395039, 228000, 215700, 143195,
#        218836, 145900, 165400, 284700,  91900,  99000, 135500,  67000,
#        135900, 168000, 188700, 198000, 257076, 311500, 224000,  13100,
#         89000,  40000, 392500, 294464, 271000, 228500, 287000, 294000,
#        293077, 264966, 298751, 209200, 206300, 160500,  94900,  81000,
#        134500, 167300, 268000, 251000, 163900, 154204, 377426, 349265,
#        591587, 392000, 441929, 455000, 182900, 192350, 143250, 142500,
#        129250, 314813, 322400, 345474, 415298, 450000, 395000, 380000,
#        440000, 418000, 500067, 260116, 317000, 319500, 325624, 372000,
#        342000, 281500, 245700, 232698, 194700, 209500, 277500, 181755,
#        171925, 179540, 176485, 156932, 177594, 194201, 185485, 206580,
#        183500, 211000, 187000, 248000, 466500, 322500, 430000, 263000,
#        330000, 260261, 282922, 255000, 235876, 248328, 249000, 307000,
#        221300, 208900, 210400, 212109, 303477, 310013, 249700, 227875,
#        261329, 265000, 120750, 143900, 302000, 193800, 194000, 199900,
#        164700, 301000, 312500, 279700, 181500, 373000, 226000, 143450,
#        136905, 103000, 140500, 117600, 224500, 101800,  39300,  64500,
#        146500, 114500, 142100, 157900, 174850, 128600, 103200, 122900,
#        102000, 169500, 108500, 144100, 153500, 104500, 128250, 153575,
#        139400, 202500, 101000,  50000, 219000, 200500, 158450, 115400,
#        165250, 243000,  86000, 383970, 200141, 276000, 155835, 195400,
#        217000, 212999, 176432, 277000, 279000, 147900, 123600, 204750,
#        235500, 190550, 267000, 246900, 179600, 168675, 183850,  98500,
#         79275, 164000,  90350, 119750, 238000, 259500, 200624, 129850,
#        150909,  75200,  68104, 119600, 231713, 267300, 265900, 248900,
#        282000, 279900, 281213,  85500, 106500,  93900,  84500, 192100,
#        457347, 545224, 356383, 556581, 361919, 535000, 438780, 188900,
#        105500,  91500, 146300, 412083, 342643, 465000, 293000, 415000,
#        326000, 309000, 275500, 338500, 344133, 298236, 372397, 374000,
#        185850, 282500, 332200, 310090, 171750, 170440, 169985, 219210,
#        174190, 172785, 210250, 246990, 167240, 213490, 264561, 192140,
#        183200, 201490, 230500, 172400, 348000, 258000, 584500, 336820,
#        232000, 199000, 198600, 232600, 200825, 187750, 186800, 248500,
#        129200, 262000, 176400, 147400, 144152, 165150, 164500, 129800,
#         98600, 134450,  99800, 108480,  68000, 159950, 133700,  81400,
#         93500,  96900,  61500, 114504, 140200, 110500,  52500,  72000,
#        119500, 148400, 274970, 136900, 123500, 183600, 239799, 294900,
#        209700, 210900, 216837, 155900, 203160, 195800, 212900, 173900,
#        163990, 164990, 117250,  97900,  92000, 104900,  35000, 138887,
#         51689,  35311, 375000, 242500, 250764, 202000, 359900,  81500,
#        151400,  79400,  87550,  90500])

# %% [markdown]
# COLUMNS THAT ARE NO IN DATABASE: ms_subclass,

# %% [markdown]
# ------------------------------------------ STOP HERE!!! ---------------------------------------------------------

# %% [markdown]
# **Export Dataframe:**

# %%
df.to_csv('../data/train_clean.csv')
